# %%
from jw_package import *
from filling_missing import *
from functools import *
# Out:
# import configuration completed !
# train + key + weather merging started
# train + key + weather merging finished
# function configuration completed !
# Good to go !

# %%
each_station = []

for station_nbr in range(1,21):
    file_path = '../data/weather_partial_mean_all_best_close/{:02}.csv'.format(station_nbr)
    station = pd.read_csv(file_path,index_col=0)
    each_station.append(station)

weather = reduce((lambda x,y : x.append(y)),each_station)

# %%
etc = ['date','day','month','year','station_nbr','store_nbr']
category = ['sunrise','sunset','codesum']

# %%
# etc = ['date','day','month','year','station_nbr']
# category = ['sunrise','sunset','codesum']

# %%
# etc = ['date','day','month','year']
# category = ['sunrise','sunset','codesum']

# %%
weather.columns
# Out:
# Index(['avgspeed', 'codesum', 'cool', 'date', 'day', 'depart', 'dewpoint',
#        'heat', 'month', 'preciptotal', 'resultdir', 'resultspeed', 'sealevel',
#        'snowfall', 'station_nbr', 'stnpressure', 'sunrise', 'sunset', 'tavg',
#        'tmax', 'tmin', 'wetbulb', 'year'],
#       dtype='object')

# %%
sales = pd.read_csv('../data/basic/train.csv')
keys = pd.read_csv('../data/basic/key.csv')

# %%
data = sales.merge(keys).merge(weather)

# %%
for each in etc+category:
    data.drop(each,axis=1,inplace=True)

# %%
data = data[data['units']!=0]

# %%
# formula = 'units ~ C(station_nbr) + C(store_nbr) + C(item_nbr)+avgspeed + cool + depart + dewpoint + heat + preciptotal + resultdir + resultspeed + sealevel + snowfall + stnpressure + tavg + tmax + tmin + wetbulb'

# %%
formula = 'units ~ C(store_nbr) + C(item_nbr)+avgspeed + cool + depart + dewpoint + heat + preciptotal + resultdir + resultspeed + sealevel + snowfall + stnpressure + tavg + tmax + tmin + wetbulb'

# %%
# formula = 'units ~ + C(item_nbr)+avgspeed + cool + depart + dewpoint + heat + preciptotal + resultdir + resultspeed + sealevel + snowfall + stnpressure + tavg + tmax + tmin + wetbulb'

# %%
# formula = 'units ~ avgspeed + cool + depart + dewpoint + heat + preciptotal + resultdir + resultspeed + sealevel + snowfall + stnpressure + tmax + tmin + wetbulb'

# %% [markdown]
# 'units ~ avgspeed + cool + depart + dewpoint + heat + preciptotal + resultdir + resultspeed + sealevel + snowfall + stnpressure + tavg + tmax + tmin + wetbulb'

# %%
data.head()
# Out:
#      store_nbr  item_nbr  units  avgspeed  cool  depart  dewpoint  heat  \
# 8            1         9     29       4.6   0.0     8.0      36.0  23.0
# 27           1        28      2       4.6   0.0     8.0      36.0  23.0
# 50           1        51      1       4.6   0.0     8.0      36.0  23.0
# 119          1         9     60      10.3   0.0    11.0      26.0  24.0
# 138          1        28      5      10.3   0.0    11.0      26.0  24.0
#
#      preciptotal  resultdir  resultspeed  sealevel  snowfall  stnpressure  \
# 8           0.05       20.0          3.6     29.92       0.0        29.78
# 27          0.05       20.0          3.6     29.92       0.0        29.78
# 50          0.05       20.0          3.6     29.92       0.0        29.78
# 119         0.01       24.0          9.8     29.62       0.0        29.44
# 138         0.01       24.0          9.8     29.62       0.0        29.44
#
#      tavg  tmax  tmin  wetbulb
# 8    42.0  52.0  31.0     40.0
# 27   42.0  52.0  31.0     40.0
# 50   42.0  52.0  31.0     40.0
# 119  41.0  50.0  31.0     35.0
# 138  41.0  50.0  31.0     35.0

# %%
model = sm.OLS.from_formula(formula,data=data)

# %%
model.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  units   R-squared:                       0.585
# Model:                            OLS   Adj. R-squared:                  0.584
# Method:                 Least Squares   F-statistic:                     986.8
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        13:23:37   Log-Likelihood:            -5.7717e+05
# No. Observations:              118696   AIC:                         1.155e+06
# Df Residuals:                  118526   BIC:                         1.156e+06
# Df Model:                         169
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept            160.3171     22.581      7.100      0.000     116.058     204.576
# C(store_nbr)[T.2]     36.7717      2.137     17.208      0.000      32.583      40.960
# C(store_nbr)[T.3]     26.8383      2.102     12.766      0.000      22.718      30.959
# C(store_nbr)[T.4]     79.6787      1.572     50.687      0.000      76.598      82.760
# C(store_nbr)[T.5]     26.9141      1.260     21.356      0.000      24.444      29.384
# C(store_nbr)[T.6]     21.5720      2.118     10.187      0.000      17.421      25.723
# C(store_nbr)[T.7]     31.7229      1.406     22.557      0.000      28.966      34.479
# C(store_nbr)[T.8]     10.9784      1.501      7.312      0.000       8.036      13.921
# C(store_nbr)[T.9]     19.8730      1.416     14.038      0.000      17.098      22.648
# C(store_nbr)[T.10]    30.8181      1.193     25.827      0.000      28.479      33.157
# C(store_nbr)[T.11]    11.3615      1.193      9.522      0.000       9.023      13.700
# C(store_nbr)[T.12]    33.5841      1.250     26.878      0.000      31.135      36.033
# C(store_nbr)[T.13]    38.9158      1.377     28.252      0.000      36.216      41.616
# C(store_nbr)[T.14]   -31.9611      1.228    -26.019      0.000     -34.369     -29.553
# C(store_nbr)[T.15]    45.1503      8.033      5.621      0.000      29.407      60.894
# C(store_nbr)[T.16]    55.7596      1.858     30.013      0.000      52.118      59.401
# C(store_nbr)[T.17]    94.6129      1.451     65.225      0.000      91.770      97.456
# C(store_nbr)[T.18]     6.8896      1.459      4.722      0.000       4.030       9.749
# C(store_nbr)[T.19]    19.5207      1.410     13.844      0.000      16.757      22.284
# C(store_nbr)[T.20]    41.1914      2.176     18.928      0.000      36.926      45.457
# C(store_nbr)[T.21]    -0.3022      1.472     -0.205      0.837      -3.186       2.582
# C(store_nbr)[T.22]    15.1438      1.185     12.781      0.000      12.821      17.466
# C(store_nbr)[T.23]    -4.1878      1.427     -2.935      0.003      -6.985      -1.391
# C(store_nbr)[T.24]    85.6117      4.621     18.528      0.000      76.555      94.668
# C(store_nbr)[T.25]    55.2566      8.027      6.884      0.000      39.523      70.990
# C(store_nbr)[T.26]     8.6965      1.421      6.119      0.000       5.911      11.482
# C(store_nbr)[T.27]     9.6504      1.168      8.260      0.000       7.360      11.940
# C(store_nbr)[T.28]     7.7136      2.123      3.633      0.000       3.552      11.875
# C(store_nbr)[T.29]    20.6123      1.532     13.453      0.000      17.609      23.615
# C(store_nbr)[T.30]    48.8433      1.502     32.523      0.000      45.900      51.787
# C(store_nbr)[T.31]    27.5610      1.369     20.130      0.000      24.878      30.245
# C(store_nbr)[T.32]    17.8175      8.022      2.221      0.026       2.094      33.541
# C(store_nbr)[T.33]    89.9042      1.439     62.457      0.000      87.083      92.726
# C(store_nbr)[T.34]    32.9230      1.367     24.079      0.000      30.243      35.603
# C(store_nbr)[T.35]    26.6402      1.733     15.376      0.000      23.244      30.036
# C(store_nbr)[T.36]   -13.7507      1.316    -10.449      0.000     -16.330     -11.171
# C(store_nbr)[T.37]    22.4169      8.035      2.790      0.005       6.669      38.165
# C(store_nbr)[T.38]    42.2127      2.086     20.233      0.000      38.124      46.302
# C(store_nbr)[T.39]   -31.4228      1.345    -23.371      0.000     -34.058     -28.788
# C(store_nbr)[T.40]    27.3040      8.033      3.399      0.001      11.560      43.048
# C(store_nbr)[T.41]    24.8642      1.207     20.608      0.000      22.499      27.229
# C(store_nbr)[T.42]    15.7530      2.145      7.344      0.000      11.549      19.957
# C(store_nbr)[T.43]    36.3406      1.274     28.515      0.000      33.843      38.838
# C(store_nbr)[T.44]    16.3272      1.217     13.419      0.000      13.942      18.712
# C(store_nbr)[T.45]   -17.5244      1.351    -12.972      0.000     -20.172     -14.876
# C(item_nbr)[T.2]     -25.2314      2.290    -11.020      0.000     -29.719     -20.744
# C(item_nbr)[T.3]     -50.9361      2.897    -17.580      0.000     -56.615     -45.257
# C(item_nbr)[T.4]       0.6764      3.190      0.212      0.832      -5.577       6.930
# C(item_nbr)[T.5]      15.4293      2.002      7.708      0.000      11.506      19.353
# C(item_nbr)[T.6]     -60.4233      4.970    -12.158      0.000     -70.164     -50.682
# C(item_nbr)[T.7]     -46.0034      2.750    -16.730      0.000     -51.393     -40.614
# C(item_nbr)[T.8]      -3.3416      2.403     -1.390      0.164      -8.052       1.369
# C(item_nbr)[T.9]      18.5671      1.968      9.436      0.000      14.711      22.424
# C(item_nbr)[T.10]    -34.3418      2.708    -12.681      0.000     -39.650     -29.034
# C(item_nbr)[T.11]    -49.0466      2.741    -17.891      0.000     -54.420     -43.674
# C(item_nbr)[T.12]    -59.3303      2.702    -21.962      0.000     -64.625     -54.035
# C(item_nbr)[T.13]    -62.3701      2.934    -21.257      0.000     -68.121     -56.619
# C(item_nbr)[T.14]    -33.5640      3.247    -10.338      0.000     -39.927     -27.201
# C(item_nbr)[T.15]    -26.5184      2.361    -11.234      0.000     -31.145     -21.892
# C(item_nbr)[T.16]    -18.9607      2.052     -9.240      0.000     -22.983     -14.939
# C(item_nbr)[T.17]    -48.9096      2.625    -18.636      0.000     -54.054     -43.766
# C(item_nbr)[T.18]    -54.4391      2.729    -19.947      0.000     -59.788     -49.090
# C(item_nbr)[T.19]    -22.0722      2.628     -8.398      0.000     -27.224     -16.921
# C(item_nbr)[T.20]    -42.6187      2.564    -16.622      0.000     -47.644     -37.593
# C(item_nbr)[T.21]    -34.9958      2.291    -15.274      0.000     -39.487     -30.505
# C(item_nbr)[T.22]      2.4736      4.070      0.608      0.543      -5.504      10.452
# C(item_nbr)[T.23]    -19.1374      2.224     -8.604      0.000     -23.497     -14.778
# C(item_nbr)[T.24]    -32.5828      2.928    -11.130      0.000     -38.321     -26.845
# C(item_nbr)[T.25]     55.6687      2.215     25.133      0.000      51.327      60.010
# C(item_nbr)[T.26]      2.7419      2.461      1.114      0.265      -2.081       7.565
# C(item_nbr)[T.27]    -86.1212      2.413    -35.695      0.000     -90.850     -81.392
# C(item_nbr)[T.28]    -13.4799      2.396     -5.626      0.000     -18.176      -8.783
# C(item_nbr)[T.29]    -10.9196      2.553     -4.277      0.000     -15.924      -5.915
# C(item_nbr)[T.30]     -1.1838      2.203     -0.537      0.591      -5.502       3.134
# C(item_nbr)[T.31]    -48.2045      2.713    -17.770      0.000     -53.521     -42.888
# C(item_nbr)[T.32]    -42.5815      2.821    -15.095      0.000     -48.111     -37.052
# C(item_nbr)[T.33]     14.1754      2.972      4.770      0.000       8.351      20.000
# C(item_nbr)[T.34]     -2.3037      4.840     -0.476      0.634     -11.790       7.182
# C(item_nbr)[T.35]    -20.2154      2.676     -7.556      0.000     -25.459     -14.971
# C(item_nbr)[T.36]     24.1750      2.216     10.910      0.000      19.832      28.518
# C(item_nbr)[T.37]    -32.6644      2.064    -15.829      0.000     -36.709     -28.620
# C(item_nbr)[T.38]    -21.3401      2.761     -7.729      0.000     -26.752     -15.928
# C(item_nbr)[T.39]    -52.6935      3.280    -16.063      0.000     -59.123     -46.264
# C(item_nbr)[T.40]    -18.8949      3.644     -5.185      0.000     -26.037     -11.753
# C(item_nbr)[T.41]    -20.4937      2.230     -9.190      0.000     -24.864     -16.123
# C(item_nbr)[T.42]    -27.8507      2.537    -10.976      0.000     -32.824     -22.878
# C(item_nbr)[T.43]    -55.0262      4.970    -11.072      0.000     -64.767     -45.285
# C(item_nbr)[T.44]     79.6934      1.968     40.501      0.000      75.837      83.550
# C(item_nbr)[T.45]     29.8723      2.003     14.917      0.000      25.947      33.797
# C(item_nbr)[T.46]    -52.3923      2.873    -18.236      0.000     -58.023     -46.761
# C(item_nbr)[T.47]    -10.7408      2.817     -3.813      0.000     -16.262      -5.220
# C(item_nbr)[T.48]     46.7884      2.549     18.355      0.000      41.792      51.784
# C(item_nbr)[T.49]    -51.2377      2.943    -17.408      0.000     -57.007     -45.469
# C(item_nbr)[T.50]    -31.8124      2.410    -13.202      0.000     -36.535     -27.089
# C(item_nbr)[T.51]    -29.0950      2.408    -12.082      0.000     -33.815     -24.375
# C(item_nbr)[T.52]    -50.6952      2.259    -22.440      0.000     -55.123     -46.267
# C(item_nbr)[T.53]    -26.4038      2.714     -9.727      0.000     -31.724     -21.084
# C(item_nbr)[T.54]    -31.3835      2.735    -11.476      0.000     -36.744     -26.023
# C(item_nbr)[T.55]    -30.3943      2.632    -11.547      0.000     -35.553     -25.235
# C(item_nbr)[T.56]    -19.6527      2.429     -8.092      0.000     -24.413     -14.892
# C(item_nbr)[T.57]    -21.6712      2.942     -7.365      0.000     -27.438     -15.904
# C(item_nbr)[T.58]    -20.2464      2.677     -7.562      0.000     -25.494     -14.999
# C(item_nbr)[T.59]    -25.9885      2.553    -10.180      0.000     -30.992     -20.985
# C(item_nbr)[T.60]   -102.1547      5.075    -20.128      0.000    -112.102     -92.207
# C(item_nbr)[T.61]    -39.6680      2.261    -17.543      0.000     -44.100     -35.236
# C(item_nbr)[T.62]    -32.1690      2.802    -11.480      0.000     -37.661     -26.677
# C(item_nbr)[T.63]    -36.3186      2.870    -12.653      0.000     -41.944     -30.693
# C(item_nbr)[T.64]    -69.1376      3.063    -22.573      0.000     -75.141     -63.134
# C(item_nbr)[T.65]    -64.7002      2.683    -24.118      0.000     -69.958     -59.442
# C(item_nbr)[T.66]    -26.0072      2.473    -10.515      0.000     -30.855     -21.159
# C(item_nbr)[T.67]    -32.9961      2.445    -13.494      0.000     -37.789     -28.204
# C(item_nbr)[T.68]      5.6601      2.062      2.745      0.006       1.619       9.701
# C(item_nbr)[T.69]    -36.1452      2.671    -13.530      0.000     -41.381     -30.909
# C(item_nbr)[T.70]     16.3706      3.091      5.296      0.000      10.313      22.429
# C(item_nbr)[T.71]   -109.4950      2.851    -38.408      0.000    -115.083    -103.907
# C(item_nbr)[T.72]    -22.4876      2.689     -8.362      0.000     -27.759     -17.217
# C(item_nbr)[T.73]    -52.2097      2.812    -18.566      0.000     -57.721     -46.698
# C(item_nbr)[T.74]    -52.5946      2.820    -18.653      0.000     -58.121     -47.068
# C(item_nbr)[T.75]    -36.8770      2.994    -12.317      0.000     -42.745     -31.009
# C(item_nbr)[T.76]   -102.5255      5.381    -19.055      0.000    -113.071     -91.980
# C(item_nbr)[T.77]    -68.4563      2.889    -23.697      0.000     -74.118     -62.794
# C(item_nbr)[T.78]    -28.9552      3.009     -9.623      0.000     -34.853     -23.058
# C(item_nbr)[T.79]    -48.6124      2.796    -17.388      0.000     -54.092     -43.133
# C(item_nbr)[T.80]    -25.3871      2.901     -8.751      0.000     -31.073     -19.701
# C(item_nbr)[T.81]    -48.0799      2.637    -18.235      0.000     -53.248     -42.912
# C(item_nbr)[T.82]    -28.7046      2.807    -10.228      0.000     -34.205     -23.204
# C(item_nbr)[T.83]    -28.5160      2.455    -11.614      0.000     -33.328     -23.704
# C(item_nbr)[T.84]    -42.0709      3.222    -13.058      0.000     -48.385     -35.756
# C(item_nbr)[T.85]    -71.9435      3.152    -22.822      0.000     -78.122     -65.765
# C(item_nbr)[T.86]    -39.0516      2.453    -15.918      0.000     -43.860     -34.243
# C(item_nbr)[T.87]    -26.5031      2.590    -10.233      0.000     -31.580     -21.427
# C(item_nbr)[T.88]    -17.0920      3.475     -4.919      0.000     -23.903     -10.281
# C(item_nbr)[T.89]    -16.5089      4.191     -3.939      0.000     -24.723      -8.295
# C(item_nbr)[T.90]    -95.8715      2.565    -37.381      0.000    -100.898     -90.845
# C(item_nbr)[T.91]    -14.0791      2.737     -5.144      0.000     -19.443      -8.715
# C(item_nbr)[T.92]   -103.3838      2.716    -38.065      0.000    -108.707     -98.061
# C(item_nbr)[T.93]    -37.0695      2.027    -18.284      0.000     -41.043     -33.096
# C(item_nbr)[T.94]    -32.0115      2.590    -12.359      0.000     -37.088     -26.935
# C(item_nbr)[T.95]     -5.6303      2.682     -2.100      0.036     -10.886      -0.374
# C(item_nbr)[T.96]    -96.3348      3.869    -24.899      0.000    -103.918     -88.751
# C(item_nbr)[T.97]    -94.7460      3.687    -25.694      0.000    -101.973     -87.519
# C(item_nbr)[T.98]    -47.6091      2.386    -19.956      0.000     -52.285     -42.933
# C(item_nbr)[T.99]    -16.7413      3.129     -5.350      0.000     -22.875     -10.608
# C(item_nbr)[T.100]   -25.2982      2.884     -8.773      0.000     -30.950     -19.646
# C(item_nbr)[T.101]   -96.3409      3.019    -31.908      0.000    -102.259     -90.423
# C(item_nbr)[T.102]   -39.0270      6.727     -5.801      0.000     -52.213     -25.841
# C(item_nbr)[T.103]    15.1150      3.398      4.448      0.000       8.455      21.775
# C(item_nbr)[T.104]   -32.4559      2.752    -11.795      0.000     -37.849     -27.063
# C(item_nbr)[T.105]   -35.1236      2.634    -13.337      0.000     -40.286     -29.962
# C(item_nbr)[T.106]   -38.8455      4.248     -9.145      0.000     -47.171     -30.520
# C(item_nbr)[T.107]   -33.0832      3.032    -10.913      0.000     -39.025     -27.142
# C(item_nbr)[T.108]   -34.9949      2.819    -12.415      0.000     -40.520     -29.470
# C(item_nbr)[T.109]   -21.8911      2.389     -9.165      0.000     -26.573     -17.209
# C(item_nbr)[T.110]   -18.9427      3.395     -5.579      0.000     -25.597     -12.288
# C(item_nbr)[T.111]    17.4282      4.309      4.045      0.000       8.983      25.874
# avgspeed              -0.3754      0.063     -5.964      0.000      -0.499      -0.252
# cool                   1.3394      0.201      6.654      0.000       0.945       1.734
# depart                -0.0020      0.020     -0.101      0.919      -0.041       0.037
# dewpoint              -0.0085      0.024     -0.351      0.726      -0.056       0.039
# heat                  -1.0218      0.199     -5.129      0.000      -1.412      -0.631
# preciptotal            0.4795      0.328      1.462      0.144      -0.164       1.122
# resultdir              0.0281      0.010      2.792      0.005       0.008       0.048
# resultspeed            0.2001      0.055      3.621      0.000       0.092       0.308
# sealevel              -4.3254      1.476     -2.931      0.003      -7.218      -1.433
# snowfall              -0.9710      0.334     -2.906      0.004      -1.626      -0.316
# stnpressure            2.1929      1.420      1.545      0.122      -0.590       4.976
# tavg                  -1.0931      0.208     -5.248      0.000      -1.501      -0.685
# tmax                  -0.1245      0.030     -4.145      0.000      -0.183      -0.066
# tmin                   0.0129      0.032      0.399      0.690      -0.050       0.076
# wetbulb                0.0121      0.043      0.282      0.778      -0.072       0.096
# ==============================================================================
# Omnibus:                   393560.326   Durbin-Watson:                   1.842
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     421855832275.486
# Skew:                          57.291   Prob(JB):                         0.00
# Kurtosis:                    9237.985   Cond. No.                     3.60e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.6e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # station_nbr 를 기존의 weather feature와 store_nbr, item_nbr와 같이 넣었을 때 그렇지 않은 결과보다 condition number가 높게 나온다.
# # 그 이유는 station_nbr에 대한 weather가 이미 feature로 고려되서 그럴 것이다

# %%
model = sm.OLS.from_formula(formula,data=data)
result = model.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  units   R-squared:                       0.585
# Model:                            OLS   Adj. R-squared:                  0.584
# Method:                 Least Squares   F-statistic:                     986.8
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        13:42:16   Log-Likelihood:            -5.7717e+05
# No. Observations:              118696   AIC:                         1.155e+06
# Df Residuals:                  118526   BIC:                         1.156e+06
# Df Model:                         169
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept            160.3171     22.581      7.100      0.000     116.058     204.576
# C(store_nbr)[T.2]     36.7717      2.137     17.208      0.000      32.583      40.960
# C(store_nbr)[T.3]     26.8383      2.102     12.766      0.000      22.718      30.959
# C(store_nbr)[T.4]     79.6787      1.572     50.687      0.000      76.598      82.760
# C(store_nbr)[T.5]     26.9141      1.260     21.356      0.000      24.444      29.384
# C(store_nbr)[T.6]     21.5720      2.118     10.187      0.000      17.421      25.723
# C(store_nbr)[T.7]     31.7229      1.406     22.557      0.000      28.966      34.479
# C(store_nbr)[T.8]     10.9784      1.501      7.312      0.000       8.036      13.921
# C(store_nbr)[T.9]     19.8730      1.416     14.038      0.000      17.098      22.648
# C(store_nbr)[T.10]    30.8181      1.193     25.827      0.000      28.479      33.157
# C(store_nbr)[T.11]    11.3615      1.193      9.522      0.000       9.023      13.700
# C(store_nbr)[T.12]    33.5841      1.250     26.878      0.000      31.135      36.033
# C(store_nbr)[T.13]    38.9158      1.377     28.252      0.000      36.216      41.616
# C(store_nbr)[T.14]   -31.9611      1.228    -26.019      0.000     -34.369     -29.553
# C(store_nbr)[T.15]    45.1503      8.033      5.621      0.000      29.407      60.894
# C(store_nbr)[T.16]    55.7596      1.858     30.013      0.000      52.118      59.401
# C(store_nbr)[T.17]    94.6129      1.451     65.225      0.000      91.770      97.456
# C(store_nbr)[T.18]     6.8896      1.459      4.722      0.000       4.030       9.749
# C(store_nbr)[T.19]    19.5207      1.410     13.844      0.000      16.757      22.284
# C(store_nbr)[T.20]    41.1914      2.176     18.928      0.000      36.926      45.457
# C(store_nbr)[T.21]    -0.3022      1.472     -0.205      0.837      -3.186       2.582
# C(store_nbr)[T.22]    15.1438      1.185     12.781      0.000      12.821      17.466
# C(store_nbr)[T.23]    -4.1878      1.427     -2.935      0.003      -6.985      -1.391
# C(store_nbr)[T.24]    85.6117      4.621     18.528      0.000      76.555      94.668
# C(store_nbr)[T.25]    55.2566      8.027      6.884      0.000      39.523      70.990
# C(store_nbr)[T.26]     8.6965      1.421      6.119      0.000       5.911      11.482
# C(store_nbr)[T.27]     9.6504      1.168      8.260      0.000       7.360      11.940
# C(store_nbr)[T.28]     7.7136      2.123      3.633      0.000       3.552      11.875
# C(store_nbr)[T.29]    20.6123      1.532     13.453      0.000      17.609      23.615
# C(store_nbr)[T.30]    48.8433      1.502     32.523      0.000      45.900      51.787
# C(store_nbr)[T.31]    27.5610      1.369     20.130      0.000      24.878      30.245
# C(store_nbr)[T.32]    17.8175      8.022      2.221      0.026       2.094      33.541
# C(store_nbr)[T.33]    89.9042      1.439     62.457      0.000      87.083      92.726
# C(store_nbr)[T.34]    32.9230      1.367     24.079      0.000      30.243      35.603
# C(store_nbr)[T.35]    26.6402      1.733     15.376      0.000      23.244      30.036
# C(store_nbr)[T.36]   -13.7507      1.316    -10.449      0.000     -16.330     -11.171
# C(store_nbr)[T.37]    22.4169      8.035      2.790      0.005       6.669      38.165
# C(store_nbr)[T.38]    42.2127      2.086     20.233      0.000      38.124      46.302
# C(store_nbr)[T.39]   -31.4228      1.345    -23.371      0.000     -34.058     -28.788
# C(store_nbr)[T.40]    27.3040      8.033      3.399      0.001      11.560      43.048
# C(store_nbr)[T.41]    24.8642      1.207     20.608      0.000      22.499      27.229
# C(store_nbr)[T.42]    15.7530      2.145      7.344      0.000      11.549      19.957
# C(store_nbr)[T.43]    36.3406      1.274     28.515      0.000      33.843      38.838
# C(store_nbr)[T.44]    16.3272      1.217     13.419      0.000      13.942      18.712
# C(store_nbr)[T.45]   -17.5244      1.351    -12.972      0.000     -20.172     -14.876
# C(item_nbr)[T.2]     -25.2314      2.290    -11.020      0.000     -29.719     -20.744
# C(item_nbr)[T.3]     -50.9361      2.897    -17.580      0.000     -56.615     -45.257
# C(item_nbr)[T.4]       0.6764      3.190      0.212      0.832      -5.577       6.930
# C(item_nbr)[T.5]      15.4293      2.002      7.708      0.000      11.506      19.353
# C(item_nbr)[T.6]     -60.4233      4.970    -12.158      0.000     -70.164     -50.682
# C(item_nbr)[T.7]     -46.0034      2.750    -16.730      0.000     -51.393     -40.614
# C(item_nbr)[T.8]      -3.3416      2.403     -1.390      0.164      -8.052       1.369
# C(item_nbr)[T.9]      18.5671      1.968      9.436      0.000      14.711      22.424
# C(item_nbr)[T.10]    -34.3418      2.708    -12.681      0.000     -39.650     -29.034
# C(item_nbr)[T.11]    -49.0466      2.741    -17.891      0.000     -54.420     -43.674
# C(item_nbr)[T.12]    -59.3303      2.702    -21.962      0.000     -64.625     -54.035
# C(item_nbr)[T.13]    -62.3701      2.934    -21.257      0.000     -68.121     -56.619
# C(item_nbr)[T.14]    -33.5640      3.247    -10.338      0.000     -39.927     -27.201
# C(item_nbr)[T.15]    -26.5184      2.361    -11.234      0.000     -31.145     -21.892
# C(item_nbr)[T.16]    -18.9607      2.052     -9.240      0.000     -22.983     -14.939
# C(item_nbr)[T.17]    -48.9096      2.625    -18.636      0.000     -54.054     -43.766
# C(item_nbr)[T.18]    -54.4391      2.729    -19.947      0.000     -59.788     -49.090
# C(item_nbr)[T.19]    -22.0722      2.628     -8.398      0.000     -27.224     -16.921
# C(item_nbr)[T.20]    -42.6187      2.564    -16.622      0.000     -47.644     -37.593
# C(item_nbr)[T.21]    -34.9958      2.291    -15.274      0.000     -39.487     -30.505
# C(item_nbr)[T.22]      2.4736      4.070      0.608      0.543      -5.504      10.452
# C(item_nbr)[T.23]    -19.1374      2.224     -8.604      0.000     -23.497     -14.778
# C(item_nbr)[T.24]    -32.5828      2.928    -11.130      0.000     -38.321     -26.845
# C(item_nbr)[T.25]     55.6687      2.215     25.133      0.000      51.327      60.010
# C(item_nbr)[T.26]      2.7419      2.461      1.114      0.265      -2.081       7.565
# C(item_nbr)[T.27]    -86.1212      2.413    -35.695      0.000     -90.850     -81.392
# C(item_nbr)[T.28]    -13.4799      2.396     -5.626      0.000     -18.176      -8.783
# C(item_nbr)[T.29]    -10.9196      2.553     -4.277      0.000     -15.924      -5.915
# C(item_nbr)[T.30]     -1.1838      2.203     -0.537      0.591      -5.502       3.134
# C(item_nbr)[T.31]    -48.2045      2.713    -17.770      0.000     -53.521     -42.888
# C(item_nbr)[T.32]    -42.5815      2.821    -15.095      0.000     -48.111     -37.052
# C(item_nbr)[T.33]     14.1754      2.972      4.770      0.000       8.351      20.000
# C(item_nbr)[T.34]     -2.3037      4.840     -0.476      0.634     -11.790       7.182
# C(item_nbr)[T.35]    -20.2154      2.676     -7.556      0.000     -25.459     -14.971
# C(item_nbr)[T.36]     24.1750      2.216     10.910      0.000      19.832      28.518
# C(item_nbr)[T.37]    -32.6644      2.064    -15.829      0.000     -36.709     -28.620
# C(item_nbr)[T.38]    -21.3401      2.761     -7.729      0.000     -26.752     -15.928
# C(item_nbr)[T.39]    -52.6935      3.280    -16.063      0.000     -59.123     -46.264
# C(item_nbr)[T.40]    -18.8949      3.644     -5.185      0.000     -26.037     -11.753
# C(item_nbr)[T.41]    -20.4937      2.230     -9.190      0.000     -24.864     -16.123
# C(item_nbr)[T.42]    -27.8507      2.537    -10.976      0.000     -32.824     -22.878
# C(item_nbr)[T.43]    -55.0262      4.970    -11.072      0.000     -64.767     -45.285
# C(item_nbr)[T.44]     79.6934      1.968     40.501      0.000      75.837      83.550
# C(item_nbr)[T.45]     29.8723      2.003     14.917      0.000      25.947      33.797
# C(item_nbr)[T.46]    -52.3923      2.873    -18.236      0.000     -58.023     -46.761
# C(item_nbr)[T.47]    -10.7408      2.817     -3.813      0.000     -16.262      -5.220
# C(item_nbr)[T.48]     46.7884      2.549     18.355      0.000      41.792      51.784
# C(item_nbr)[T.49]    -51.2377      2.943    -17.408      0.000     -57.007     -45.469
# C(item_nbr)[T.50]    -31.8124      2.410    -13.202      0.000     -36.535     -27.089
# C(item_nbr)[T.51]    -29.0950      2.408    -12.082      0.000     -33.815     -24.375
# C(item_nbr)[T.52]    -50.6952      2.259    -22.440      0.000     -55.123     -46.267
# C(item_nbr)[T.53]    -26.4038      2.714     -9.727      0.000     -31.724     -21.084
# C(item_nbr)[T.54]    -31.3835      2.735    -11.476      0.000     -36.744     -26.023
# C(item_nbr)[T.55]    -30.3943      2.632    -11.547      0.000     -35.553     -25.235
# C(item_nbr)[T.56]    -19.6527      2.429     -8.092      0.000     -24.413     -14.892
# C(item_nbr)[T.57]    -21.6712      2.942     -7.365      0.000     -27.438     -15.904
# C(item_nbr)[T.58]    -20.2464      2.677     -7.562      0.000     -25.494     -14.999
# C(item_nbr)[T.59]    -25.9885      2.553    -10.180      0.000     -30.992     -20.985
# C(item_nbr)[T.60]   -102.1547      5.075    -20.128      0.000    -112.102     -92.207
# C(item_nbr)[T.61]    -39.6680      2.261    -17.543      0.000     -44.100     -35.236
# C(item_nbr)[T.62]    -32.1690      2.802    -11.480      0.000     -37.661     -26.677
# C(item_nbr)[T.63]    -36.3186      2.870    -12.653      0.000     -41.944     -30.693
# C(item_nbr)[T.64]    -69.1376      3.063    -22.573      0.000     -75.141     -63.134
# C(item_nbr)[T.65]    -64.7002      2.683    -24.118      0.000     -69.958     -59.442
# C(item_nbr)[T.66]    -26.0072      2.473    -10.515      0.000     -30.855     -21.159
# C(item_nbr)[T.67]    -32.9961      2.445    -13.494      0.000     -37.789     -28.204
# C(item_nbr)[T.68]      5.6601      2.062      2.745      0.006       1.619       9.701
# C(item_nbr)[T.69]    -36.1452      2.671    -13.530      0.000     -41.381     -30.909
# C(item_nbr)[T.70]     16.3706      3.091      5.296      0.000      10.313      22.429
# C(item_nbr)[T.71]   -109.4950      2.851    -38.408      0.000    -115.083    -103.907
# C(item_nbr)[T.72]    -22.4876      2.689     -8.362      0.000     -27.759     -17.217
# C(item_nbr)[T.73]    -52.2097      2.812    -18.566      0.000     -57.721     -46.698
# C(item_nbr)[T.74]    -52.5946      2.820    -18.653      0.000     -58.121     -47.068
# C(item_nbr)[T.75]    -36.8770      2.994    -12.317      0.000     -42.745     -31.009
# C(item_nbr)[T.76]   -102.5255      5.381    -19.055      0.000    -113.071     -91.980
# C(item_nbr)[T.77]    -68.4563      2.889    -23.697      0.000     -74.118     -62.794
# C(item_nbr)[T.78]    -28.9552      3.009     -9.623      0.000     -34.853     -23.058
# C(item_nbr)[T.79]    -48.6124      2.796    -17.388      0.000     -54.092     -43.133
# C(item_nbr)[T.80]    -25.3871      2.901     -8.751      0.000     -31.073     -19.701
# C(item_nbr)[T.81]    -48.0799      2.637    -18.235      0.000     -53.248     -42.912
# C(item_nbr)[T.82]    -28.7046      2.807    -10.228      0.000     -34.205     -23.204
# C(item_nbr)[T.83]    -28.5160      2.455    -11.614      0.000     -33.328     -23.704
# C(item_nbr)[T.84]    -42.0709      3.222    -13.058      0.000     -48.385     -35.756
# C(item_nbr)[T.85]    -71.9435      3.152    -22.822      0.000     -78.122     -65.765
# C(item_nbr)[T.86]    -39.0516      2.453    -15.918      0.000     -43.860     -34.243
# C(item_nbr)[T.87]    -26.5031      2.590    -10.233      0.000     -31.580     -21.427
# C(item_nbr)[T.88]    -17.0920      3.475     -4.919      0.000     -23.903     -10.281
# C(item_nbr)[T.89]    -16.5089      4.191     -3.939      0.000     -24.723      -8.295
# C(item_nbr)[T.90]    -95.8715      2.565    -37.381      0.000    -100.898     -90.845
# C(item_nbr)[T.91]    -14.0791      2.737     -5.144      0.000     -19.443      -8.715
# C(item_nbr)[T.92]   -103.3838      2.716    -38.065      0.000    -108.707     -98.061
# C(item_nbr)[T.93]    -37.0695      2.027    -18.284      0.000     -41.043     -33.096
# C(item_nbr)[T.94]    -32.0115      2.590    -12.359      0.000     -37.088     -26.935
# C(item_nbr)[T.95]     -5.6303      2.682     -2.100      0.036     -10.886      -0.374
# C(item_nbr)[T.96]    -96.3348      3.869    -24.899      0.000    -103.918     -88.751
# C(item_nbr)[T.97]    -94.7460      3.687    -25.694      0.000    -101.973     -87.519
# C(item_nbr)[T.98]    -47.6091      2.386    -19.956      0.000     -52.285     -42.933
# C(item_nbr)[T.99]    -16.7413      3.129     -5.350      0.000     -22.875     -10.608
# C(item_nbr)[T.100]   -25.2982      2.884     -8.773      0.000     -30.950     -19.646
# C(item_nbr)[T.101]   -96.3409      3.019    -31.908      0.000    -102.259     -90.423
# C(item_nbr)[T.102]   -39.0270      6.727     -5.801      0.000     -52.213     -25.841
# C(item_nbr)[T.103]    15.1150      3.398      4.448      0.000       8.455      21.775
# C(item_nbr)[T.104]   -32.4559      2.752    -11.795      0.000     -37.849     -27.063
# C(item_nbr)[T.105]   -35.1236      2.634    -13.337      0.000     -40.286     -29.962
# C(item_nbr)[T.106]   -38.8455      4.248     -9.145      0.000     -47.171     -30.520
# C(item_nbr)[T.107]   -33.0832      3.032    -10.913      0.000     -39.025     -27.142
# C(item_nbr)[T.108]   -34.9949      2.819    -12.415      0.000     -40.520     -29.470
# C(item_nbr)[T.109]   -21.8911      2.389     -9.165      0.000     -26.573     -17.209
# C(item_nbr)[T.110]   -18.9427      3.395     -5.579      0.000     -25.597     -12.288
# C(item_nbr)[T.111]    17.4282      4.309      4.045      0.000       8.983      25.874
# avgspeed              -0.3754      0.063     -5.964      0.000      -0.499      -0.252
# cool                   1.3394      0.201      6.654      0.000       0.945       1.734
# depart                -0.0020      0.020     -0.101      0.919      -0.041       0.037
# dewpoint              -0.0085      0.024     -0.351      0.726      -0.056       0.039
# heat                  -1.0218      0.199     -5.129      0.000      -1.412      -0.631
# preciptotal            0.4795      0.328      1.462      0.144      -0.164       1.122
# resultdir              0.0281      0.010      2.792      0.005       0.008       0.048
# resultspeed            0.2001      0.055      3.621      0.000       0.092       0.308
# sealevel              -4.3254      1.476     -2.931      0.003      -7.218      -1.433
# snowfall              -0.9710      0.334     -2.906      0.004      -1.626      -0.316
# stnpressure            2.1929      1.420      1.545      0.122      -0.590       4.976
# tavg                  -1.0931      0.208     -5.248      0.000      -1.501      -0.685
# tmax                  -0.1245      0.030     -4.145      0.000      -0.183      -0.066
# tmin                   0.0129      0.032      0.399      0.690      -0.050       0.076
# wetbulb                0.0121      0.043      0.282      0.778      -0.072       0.096
# ==============================================================================
# Omnibus:                   393560.326   Durbin-Watson:                   1.842
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     421855832275.486
# Skew:                          57.291   Prob(JB):                         0.00
# Kurtosis:                    9237.985   Cond. No.                     3.60e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.6e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# fig = plt.figure(figsize=(8,20))
# sm.graphics.plot_partregress_grid(model.fit(), fig=fig)
# fig.suptitle("")
# plt.show()

# %%
res = result.resid_pearson
index = result.resid.index
outlier_index = abs(res) >= 2

row = pd.Series(index=index, data=res)
drop_index = row[outlier_index].index

# %%
data.drop(list(drop_index),inplace=True)

# %%
model = sm.OLS.from_formula(formula,data=data)
result = model.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  units   R-squared:                       0.861
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     3673.
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        13:45:19   Log-Likelihood:            -3.8185e+05
# No. Observations:              100435   AIC:                         7.640e+05
# Df Residuals:                  100265   BIC:                         7.657e+05
# Df Model:                         169
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             70.2184      8.611      8.155      0.000      53.342      87.095
# C(store_nbr)[T.2]     33.6233      0.799     42.067      0.000      32.057      35.190
# C(store_nbr)[T.3]     19.3212      0.773     25.001      0.000      17.807      20.836
# C(store_nbr)[T.4]     72.8391      0.720    101.186      0.000      71.428      74.250
# C(store_nbr)[T.5]     11.5903      0.464     24.976      0.000      10.681      12.500
# C(store_nbr)[T.6]     17.4716      0.779     22.425      0.000      15.945      18.999
# C(store_nbr)[T.7]     23.1387      0.539     42.889      0.000      22.081      24.196
# C(store_nbr)[T.8]      7.3322      0.556     13.185      0.000       6.242       8.422
# C(store_nbr)[T.9]     17.6376      0.526     33.553      0.000      16.607      18.668
# C(store_nbr)[T.10]    16.0929      0.451     35.705      0.000      15.210      16.976
# C(store_nbr)[T.11]    10.8366      0.444     24.428      0.000       9.967      11.706
# C(store_nbr)[T.12]    17.4142      0.461     37.734      0.000      16.510      18.319
# C(store_nbr)[T.13]    31.8257      0.525     60.615      0.000      30.797      32.855
# C(store_nbr)[T.14]   -26.8279      0.501    -53.540      0.000     -27.810     -25.846
# C(store_nbr)[T.15]    33.4969      2.913     11.499      0.000      27.787      39.206
# C(store_nbr)[T.16]    26.6542      0.698     38.201      0.000      25.287      28.022
# C(store_nbr)[T.17]    67.1304      0.584    114.855      0.000      65.985      68.276
# C(store_nbr)[T.18]     1.6343      0.533      3.065      0.002       0.589       2.679
# C(store_nbr)[T.19]     6.5289      0.516     12.652      0.000       5.517       7.540
# C(store_nbr)[T.20]    26.2408      0.811     32.344      0.000      24.651      27.831
# C(store_nbr)[T.21]     6.8880      0.555     12.406      0.000       5.800       7.976
# C(store_nbr)[T.22]    13.2375      0.445     29.778      0.000      12.366      14.109
# C(store_nbr)[T.23]    -3.3684      0.522     -6.449      0.000      -4.392      -2.345
# C(store_nbr)[T.24]    74.2286      1.702     43.615      0.000      70.893      77.564
# C(store_nbr)[T.25]    42.6273      2.911     14.643      0.000      36.922      48.333
# C(store_nbr)[T.26]     5.5902      0.525     10.646      0.000       4.561       6.619
# C(store_nbr)[T.27]     7.5512      0.432     17.475      0.000       6.704       8.398
# C(store_nbr)[T.28]     5.9984      0.774      7.746      0.000       4.481       7.516
# C(store_nbr)[T.29]    15.1492      0.566     26.784      0.000      14.041      16.258
# C(store_nbr)[T.30]    22.5129      0.593     37.972      0.000      21.351      23.675
# C(store_nbr)[T.31]    25.4331      0.513     49.579      0.000      24.428      26.439
# C(store_nbr)[T.32]    16.4178      2.907      5.648      0.000      10.720      22.115
# C(store_nbr)[T.33]    90.6238      0.639    141.848      0.000      89.372      91.876
# C(store_nbr)[T.34]    28.7217      0.516     55.634      0.000      27.710      29.734
# C(store_nbr)[T.35]    12.6484      0.631     20.033      0.000      11.411      13.886
# C(store_nbr)[T.36]    -4.3140      0.503     -8.569      0.000      -5.301      -3.327
# C(store_nbr)[T.37]    17.7235      2.911      6.089      0.000      12.018      23.429
# C(store_nbr)[T.38]    33.2357      0.770     43.170      0.000      31.727      34.745
# C(store_nbr)[T.39]   -27.5201      0.489    -56.301      0.000     -28.478     -26.562
# C(store_nbr)[T.40]    24.1902      2.912      8.307      0.000      18.483      29.898
# C(store_nbr)[T.41]    14.1410      0.448     31.580      0.000      13.263      15.019
# C(store_nbr)[T.42]    14.4943      0.787     18.418      0.000      12.952      16.037
# C(store_nbr)[T.43]    15.9768      0.476     33.536      0.000      15.043      16.911
# C(store_nbr)[T.44]    15.3968      0.454     33.943      0.000      14.508      16.286
# C(store_nbr)[T.45]   -17.0459      0.499    -34.158      0.000     -18.024     -16.068
# C(item_nbr)[T.2]     -11.7103      0.816    -14.344      0.000     -13.310     -10.110
# C(item_nbr)[T.3]     -21.2566      1.028    -20.672      0.000     -23.272     -19.241
# C(item_nbr)[T.4]      10.5498      1.125      9.375      0.000       8.344      12.755
# C(item_nbr)[T.5]      19.0829      0.719     26.558      0.000      17.675      20.491
# C(item_nbr)[T.6]     -50.5843      1.831    -27.630      0.000     -54.173     -46.996
# C(item_nbr)[T.7]     -27.8274      0.987    -28.201      0.000     -29.761     -25.893
# C(item_nbr)[T.8]       6.0136      0.871      6.900      0.000       4.306       7.722
# C(item_nbr)[T.9]      23.5879      0.702     33.578      0.000      22.211      24.965
# C(item_nbr)[T.10]    -22.2520      0.962    -23.136      0.000     -24.137     -20.367
# C(item_nbr)[T.11]    -36.2656      0.983    -36.908      0.000     -38.191     -34.340
# C(item_nbr)[T.12]    -36.4265      0.967    -37.654      0.000     -38.323     -34.530
# C(item_nbr)[T.13]    -26.3827      1.066    -24.751      0.000     -28.472     -24.293
# C(item_nbr)[T.14]    -20.2801      1.146    -17.695      0.000     -22.526     -18.034
# C(item_nbr)[T.15]    -15.6915      0.864    -18.158      0.000     -17.385     -13.998
# C(item_nbr)[T.16]      5.8473      0.744      7.864      0.000       4.390       7.305
# C(item_nbr)[T.17]    -27.0886      0.937    -28.895      0.000     -28.926     -25.251
# C(item_nbr)[T.18]    -29.6426      0.983    -30.156      0.000     -31.569     -27.716
# C(item_nbr)[T.19]    -10.4864      0.930    -11.273      0.000     -12.310      -8.663
# C(item_nbr)[T.20]    -17.8568      0.912    -19.581      0.000     -19.644     -16.069
# C(item_nbr)[T.21]    -17.6284      0.817    -21.564      0.000     -19.231     -16.026
# C(item_nbr)[T.22]     11.2252      1.426      7.873      0.000       8.431      14.020
# C(item_nbr)[T.23]     -3.5292      0.804     -4.391      0.000      -5.105      -1.954
# C(item_nbr)[T.24]     -9.9577      1.038     -9.593      0.000     -11.992      -7.923
# C(item_nbr)[T.25]     38.2646      0.847     45.171      0.000      36.604      39.925
# C(item_nbr)[T.26]     12.7243      0.879     14.483      0.000      11.002      14.446
# C(item_nbr)[T.27]    -68.3375      0.962    -71.002      0.000     -70.224     -66.451
# C(item_nbr)[T.28]     -3.0383      0.855     -3.555      0.000      -4.714      -1.363
# C(item_nbr)[T.29]     -1.7835      0.905     -1.970      0.049      -3.558      -0.009
# C(item_nbr)[T.30]     -1.0414      0.763     -1.365      0.172      -2.537       0.454
# C(item_nbr)[T.31]    -33.8637      0.967    -35.036      0.000     -35.758     -31.969
# C(item_nbr)[T.32]    -17.7574      0.999    -17.779      0.000     -19.715     -15.800
# C(item_nbr)[T.33]     19.7428      1.071     18.442      0.000      17.645      21.841
# C(item_nbr)[T.34]      9.7556      1.690      5.773      0.000       6.443      13.068
# C(item_nbr)[T.35]     -8.6772      0.949     -9.148      0.000     -10.536      -6.818
# C(item_nbr)[T.36]     31.4377      0.801     39.249      0.000      29.868      33.008
# C(item_nbr)[T.37]     -6.4909      0.745     -8.710      0.000      -7.951      -5.030
# C(item_nbr)[T.38]     -6.7674      0.978     -6.918      0.000      -8.685      -4.850
# C(item_nbr)[T.39]    -20.5820      1.159    -17.762      0.000     -22.853     -18.311
# C(item_nbr)[T.40]     -6.8998      1.279     -5.396      0.000      -9.406      -4.394
# C(item_nbr)[T.41]     -1.2281      0.807     -1.521      0.128      -2.811       0.354
# C(item_nbr)[T.42]    -15.7804      0.904    -17.452      0.000     -17.553     -14.008
# C(item_nbr)[T.43]    -32.6740      1.823    -17.920      0.000     -36.248     -29.100
# C(item_nbr)[T.44]     70.6643      0.711     99.356      0.000      69.270      72.058
# C(item_nbr)[T.45]     39.0653      0.719     54.350      0.000      37.656      40.474
# C(item_nbr)[T.46]    -35.8110      1.025    -34.932      0.000     -37.820     -33.802
# C(item_nbr)[T.47]     -0.5118      0.998     -0.513      0.608      -2.468       1.444
# C(item_nbr)[T.48]     84.4872      1.074     78.664      0.000      82.382      86.592
# C(item_nbr)[T.49]    -24.4913      1.046    -23.423      0.000     -26.541     -22.442
# C(item_nbr)[T.50]    -27.2302      0.935    -29.116      0.000     -29.063     -25.397
# C(item_nbr)[T.51]    -12.7442      0.857    -14.872      0.000     -14.424     -11.065
# C(item_nbr)[T.52]    -34.5996      0.810    -42.716      0.000     -36.187     -33.012
# C(item_nbr)[T.53]    -11.4907      0.962    -11.939      0.000     -13.377      -9.604
# C(item_nbr)[T.54]    -19.9362      0.970    -20.545      0.000     -21.838     -18.034
# C(item_nbr)[T.55]    -17.1920      0.936    -18.375      0.000     -19.026     -15.358
# C(item_nbr)[T.56]     -8.0602      0.864     -9.334      0.000      -9.753      -6.368
# C(item_nbr)[T.57]     -6.5348      1.038     -6.297      0.000      -8.569      -4.501
# C(item_nbr)[T.58]     -8.8806      0.947     -9.380      0.000     -10.736      -7.025
# C(item_nbr)[T.59]    -12.7490      0.911    -13.995      0.000     -14.534     -10.964
# C(item_nbr)[T.60]    -79.7453      1.852    -43.053      0.000     -83.376     -76.115
# C(item_nbr)[T.61]    -21.5889      0.807    -26.741      0.000     -23.171     -20.007
# C(item_nbr)[T.62]    -21.6369      0.993    -21.793      0.000     -23.583     -19.691
# C(item_nbr)[T.63]    -13.8545      1.019    -13.599      0.000     -15.851     -11.858
# C(item_nbr)[T.64]    -29.4711      1.094    -26.932      0.000     -31.616     -27.326
# C(item_nbr)[T.65]    -27.9000      0.983    -28.377      0.000     -29.827     -25.973
# C(item_nbr)[T.66]     -3.4078      0.885     -3.852      0.000      -5.141      -1.674
# C(item_nbr)[T.67]    -20.8870      0.874    -23.885      0.000     -22.601     -19.173
# C(item_nbr)[T.68]     14.1342      0.740     19.089      0.000      12.683      15.585
# C(item_nbr)[T.69]    -12.3885      0.950    -13.041      0.000     -14.250     -10.526
# C(item_nbr)[T.70]     21.2361      1.110     19.128      0.000      19.060      23.412
# C(item_nbr)[T.71]    -72.2188      1.035    -69.755      0.000     -74.248     -70.190
# C(item_nbr)[T.72]     -7.2048      0.952     -7.569      0.000      -9.071      -5.339
# C(item_nbr)[T.73]    -22.4543      0.999    -22.466      0.000     -24.413     -20.495
# C(item_nbr)[T.74]    -28.2472      1.013    -27.883      0.000     -30.233     -26.262
# C(item_nbr)[T.75]    -12.5537      1.059    -11.853      0.000     -14.630     -10.478
# C(item_nbr)[T.76]    -79.6802      1.953    -40.802      0.000     -83.508     -75.853
# C(item_nbr)[T.77]    -29.2898      1.036    -28.276      0.000     -31.320     -27.260
# C(item_nbr)[T.78]    -17.5172      1.063    -16.475      0.000     -19.601     -15.433
# C(item_nbr)[T.79]    -22.9495      0.991    -23.164      0.000     -24.891     -21.008
# C(item_nbr)[T.80]    -13.9580      1.024    -13.635      0.000     -15.964     -11.952
# C(item_nbr)[T.81]    -25.5531      0.946    -27.021      0.000     -27.407     -23.700
# C(item_nbr)[T.82]    -17.8066      0.997    -17.862      0.000     -19.761     -15.853
# C(item_nbr)[T.83]     -4.8667      0.877     -5.548      0.000      -6.586      -3.147
# C(item_nbr)[T.84]    -25.7137      1.133    -22.689      0.000     -27.935     -23.492
# C(item_nbr)[T.85]    -34.4070      1.249    -27.550      0.000     -36.855     -31.959
# C(item_nbr)[T.86]    -21.0363      0.870    -24.188      0.000     -22.741     -19.332
# C(item_nbr)[T.87]    -16.5335      0.920    -17.977      0.000     -18.336     -14.731
# C(item_nbr)[T.88]     -1.9629      1.244     -1.579      0.114      -4.400       0.474
# C(item_nbr)[T.89]     -6.2307      1.466     -4.251      0.000      -9.104      -3.358
# C(item_nbr)[T.90]    -77.9380      1.008    -77.294      0.000     -79.914     -75.962
# C(item_nbr)[T.91]    -11.4643      0.970    -11.813      0.000     -13.366      -9.562
# C(item_nbr)[T.92]    -94.6992      1.017    -93.084      0.000     -96.693     -92.705
# C(item_nbr)[T.93]    -19.2215      0.728    -26.396      0.000     -20.649     -17.794
# C(item_nbr)[T.94]    -21.6571      0.921    -23.509      0.000     -23.463     -19.852
# C(item_nbr)[T.95]     11.6263      0.969     12.004      0.000       9.728      13.525
# C(item_nbr)[T.96]    -75.9387      1.423    -53.364      0.000     -78.728     -73.150
# C(item_nbr)[T.97]    -75.9447      1.371    -55.404      0.000     -78.631     -73.258
# C(item_nbr)[T.98]    -32.6558      0.851    -38.374      0.000     -34.324     -30.988
# C(item_nbr)[T.99]     -5.9469      1.103     -5.392      0.000      -8.109      -3.785
# C(item_nbr)[T.100]   -12.1152      1.023    -11.848      0.000     -14.119     -10.111
# C(item_nbr)[T.101]   -78.0400      1.149    -67.894      0.000     -80.293     -75.787
# C(item_nbr)[T.102]   -22.4460      2.340     -9.592      0.000     -27.032     -17.860
# C(item_nbr)[T.103]    21.4616      1.192     18.004      0.000      19.125      23.798
# C(item_nbr)[T.104]   -18.6592      0.972    -19.205      0.000     -20.563     -16.755
# C(item_nbr)[T.105]   -17.3891      0.932    -18.655      0.000     -19.216     -15.562
# C(item_nbr)[T.106]   -21.8448      1.486    -14.702      0.000     -24.757     -18.933
# C(item_nbr)[T.107]   -19.5048      1.073    -18.176      0.000     -21.608     -17.402
# C(item_nbr)[T.108]   -14.8158      0.998    -14.841      0.000     -16.772     -12.859
# C(item_nbr)[T.109]   -11.9300      0.850    -14.039      0.000     -13.596     -10.264
# C(item_nbr)[T.110]   -10.8176      1.209     -8.945      0.000     -13.188      -8.447
# C(item_nbr)[T.111]    23.4569      1.504     15.591      0.000      20.508      26.406
# avgspeed              -0.1938      0.024     -8.095      0.000      -0.241      -0.147
# cool                   0.4212      0.078      5.419      0.000       0.269       0.574
# depart                 0.0073      0.007      0.970      0.332      -0.007       0.022
# dewpoint              -0.0474      0.009     -5.274      0.000      -0.065      -0.030
# heat                  -0.3239      0.077     -4.210      0.000      -0.475      -0.173
# preciptotal            0.5446      0.121      4.491      0.000       0.307       0.782
# resultdir              0.0110      0.004      2.900      0.004       0.004       0.018
# resultspeed            0.0725      0.021      3.450      0.001       0.031       0.114
# sealevel              -3.4974      0.538     -6.498      0.000      -4.552      -2.442
# snowfall              -0.0019      0.128     -0.015      0.988      -0.253       0.249
# stnpressure            2.2691      0.514      4.411      0.000       1.261       3.277
# tavg                  -0.3582      0.080     -4.463      0.000      -0.515      -0.201
# tmax                  -0.0420      0.011     -3.754      0.000      -0.064      -0.020
# tmin                   0.0360      0.012      2.977      0.003       0.012       0.060
# wetbulb                0.0329      0.016      2.054      0.040       0.001       0.064
# ==============================================================================
# Omnibus:                     2291.296   Durbin-Watson:                   1.900
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2671.404
# Skew:                           0.327   Prob(JB):                         0.00
# Kurtosis:                       3.460   Cond. No.                     3.63e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.63e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
def vif(dfX0):
    from statsmodels.stats.outliers_influence import variance_inflation_factor
    vif = pd.DataFrame()
    vif["vif"] = [variance_inflation_factor(dfX0.values, i) for i in range(dfX0.shape[1])]
    vif["features"] = dfX0.columns
    vif.sort_values(by='vif',ascending=False, inplace=True)
    
    return vif

# %%
tmp = data.copy()

# %%
a = ['item_nbr','units']
for each in a:
    tmp.drop(each,axis=1,inplace=True)

# %%
vif(tmp)
# Out:
#              vif     features
# 11  14652.410606         tavg
# 8   14292.978748     sealevel
# 4     879.227767         heat
# 14    572.794438      wetbulb
# 12    568.433221         tmax
# 10    420.274818  stnpressure
# 13    338.634075         tmin
# 1     298.094001         cool
# 3     136.537959     dewpoint
# 0      32.991818     avgspeed
# 7      20.866127  resultspeed
# 6       5.063728    resultdir
# 2       2.495510       depart
# 5       1.216865  preciptotal
# 9       1.114970     snowfall

# %%
tmp.drop('tavg',axis=1,inplace=True)
tmp.drop('sealevel',axis=1,inplace=True)

# %%
vif(tmp)
# Out:
#            vif     features
# 12  564.142056      wetbulb
# 9   299.572986  stnpressure
# 11  200.577984         tmin
# 10  189.583120         tmax
# 3   131.727765     dewpoint
# 0    31.587775     avgspeed
# 4    20.736767         heat
# 7    20.295075  resultspeed
# 1     9.647145         cool
# 6     5.005471    resultdir
# 2     2.492154       depart
# 5     1.215340  preciptotal
# 8     1.113194     snowfall

# %%
vif(tmp)
# Out:
#            vif     features
# 9   287.147402  stnpressure
# 11  171.029572         tmin
# 10  139.169014         tmax
# 3    64.515873     dewpoint
# 0    31.578181     avgspeed
# 4    20.486034         heat
# 7    20.255864  resultspeed
# 1     9.630362         cool
# 6     5.005459    resultdir
# 2     2.476593       depart
# 5     1.212940  preciptotal
# 8     1.113124     snowfall

# %%
tmp.drop('stnpressure',axis=1,inplace=True)
vif(tmp)
# Out:
#            vif     features
# 10  138.430705         tmin
# 9    67.778409         tmax
# 3    57.845716     dewpoint
# 0    29.118660     avgspeed
# 7    18.485110  resultspeed
# 6     4.967214    resultdir
# 1     3.688091         cool
# 4     2.513277         heat
# 2     2.447377       depart
# 5     1.212883  preciptotal
# 8     1.102904     snowfall

# %%
tmp.drop('tmin',axis=1,inplace=True)

# %%
vif(tmp)
# Out:
#          vif     features
# 9  38.927114         tmax
# 3  29.764037     dewpoint
# 0  28.892842     avgspeed
# 7  18.414832  resultspeed
# 6   4.958111    resultdir
# 1   3.107476         cool
# 2   2.444529       depart
# 4   2.296742         heat
# 5   1.209242  preciptotal
# 8   1.102904     snowfall

# %%
tmp.drop('tmax',axis=1,inplace=True)
vif(tmp)
# Out:
#          vif     features
# 0  24.973485     avgspeed
# 7  16.928010  resultspeed
# 3   7.973015     dewpoint
# 6   4.491019    resultdir
# 1   3.065566         cool
# 2   2.426866       depart
# 4   2.275303         heat
# 5   1.155074  preciptotal
# 8   1.097728     snowfall

# %%
tmp.drop('avgspeed',axis=1,inplace=True)
vif(tmp)
# Out:
#         vif     features
# 2  7.246957     dewpoint
# 5  4.289320    resultdir
# 6  3.466973  resultspeed
# 0  3.048391         cool
# 1  2.421736       depart
# 3  2.167398         heat
# 4  1.148081  preciptotal
# 7  1.097551     snowfall

# %%
vif(tmp)['features'].values
# Out:
# array(['dewpoint', 'resultdir', 'resultspeed', 'cool', 'depart', 'heat',
#        'preciptotal', 'snowfall'], dtype=object)
