# %%
from set_math import *
# Out:
# sympy imported
# pandas imported
# numpy imported
# scipy imported
# statsmodels imported
# statsmodels.formula imported
# statasmodels.stats.api imported
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# # load and merge data

# %%
train = pd.read_csv("../data/basic/train.csv")
key = pd.read_csv("../data/basic/key.csv")
weather1 = pd.read_csv("../data/weather_v8_with_holiday.csv", index_col = 0)

# %%
df = pd.merge(train, key)

# %%
df1 = pd.merge(df, weather1)
print(df1.shape)
print(df1.columns)
df1.head()
# Out:
# (4617600, 26)
# Index(['date', 'store_nbr', 'item_nbr', 'units', 'station_nbr', 'tmax', 'tmin',
#        'tavg', 'depart', 'dewpoint', 'wetbulb', 'heat', 'cool', 'sunrise',
#        'sunset', 'codesum', 'codesum_YN', 'snowfall', 'preciptotal',
#        'stnpressure', 'sealevel', 'resultspeed', 'resultdir', 'avgspeed',
#        'dayofweek', 'is_holiday'],
#       dtype='object')
#          date  store_nbr  item_nbr  units  station_nbr  tmax  tmin  tavg  \
# 0  2012-01-01          1         1      0            1  52.0  31.0  42.0
# 1  2012-01-01          1         2      0            1  52.0  31.0  42.0
# 2  2012-01-01          1         3      0            1  52.0  31.0  42.0
# 3  2012-01-01          1         4      0            1  52.0  31.0  42.0
# 4  2012-01-01          1         5      0            1  52.0  31.0  42.0
#
#    depart  dewpoint     ...      codesum_YN  snowfall  preciptotal  \
# 0     0.0      36.0     ...               1      0.05         0.05
# 1     0.0      36.0     ...               1      0.05         0.05
# 2     0.0      36.0     ...               1      0.05         0.05
# 3     0.0      36.0     ...               1      0.05         0.05
# 4     0.0      36.0     ...               1      0.05         0.05
#
#    stnpressure  sealevel resultspeed  resultdir  avgspeed  dayofweek  \
# 0        29.78     29.92         3.6       20.0       4.6        Sun
# 1        29.78     29.92         3.6       20.0       4.6        Sun
# 2        29.78     29.92         3.6       20.0       4.6        Sun
# 3        29.78     29.92         3.6       20.0       4.6        Sun
# 4        29.78     29.92         3.6       20.0       4.6        Sun
#
#    is_holiday
# 0     holiday
# 1     holiday
# 2     holiday
# 3     holiday
# 4     holiday
#
# [5 rows x 26 columns]

# %%
df_test = df1

# %% [markdown]
# # 아무런 처리 없이 전부 다 넣어보기

# %%
df_test.columns
# Out:
# Index(['date', 'store_nbr', 'item_nbr', 'units', 'station_nbr', 'tmax', 'tmin',
#        'tavg', 'depart', 'dewpoint', 'wetbulb', 'heat', 'cool', 'sunrise',
#        'sunset', 'codesum', 'codesum_YN', 'snowfall', 'preciptotal',
#        'stnpressure', 'sealevel', 'resultspeed', 'resultdir', 'avgspeed',
#        'dayofweek', 'is_holiday'],
#       dtype='object')

# %%
features = ['date', 'store_nbr', 'item_nbr', 'units', 'station_nbr', 'tmax', 'tmin',
       'tavg', 'depart', 'dewpoint', 'wetbulb', 'heat', 'cool', 'sunrise',
       'sunset', 'codesum', 'codesum_YN', 'snowfall', 'preciptotal',
       'stnpressure', 'sealevel', 'resultspeed', 'resultdir', 'avgspeed',
       'dayofweek', 'is_holiday']
features = " ".join(features)
features = features.replace(" ", " + ")
features
# Out:
# 'date + store_nbr + item_nbr + units + station_nbr + tmax + tmin + tavg + depart + dewpoint + wetbulb + heat + cool + sunrise + sunset + codesum + codesum_YN + snowfall + preciptotal + stnpressure + sealevel + resultspeed + resultdir + avgspeed + dayofweek + is_holiday'

# %%
model_1 = sm.OLS.from_formula('units ~ C(item_nbr) + tmax + tmin + tavg + depart + dewpoint + wetbulb + heat + cool + sunrise + sunset + C(codesum_YN) + snowfall + preciptotal + stnpressure + sealevel + resultspeed + resultdir + avgspeed + C(is_holiday) + 0', data=df_test)
result_1 = model_1.fit()
print(result_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  units   R-squared:                       0.153
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                     6413.
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        01:56:31   Log-Likelihood:            -1.6744e+07
# No. Observations:             4617600   AIC:                         3.349e+07
# Df Residuals:                 4617469   BIC:                         3.349e+07
# Df Model:                         130
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# C(item_nbr)[1]                    3.8847      0.808      4.808      0.000       2.301       5.468
# C(item_nbr)[2]                    3.9446      0.808      4.883      0.000       2.361       5.528
# C(item_nbr)[3]                    3.8823      0.808      4.805      0.000       2.299       5.466
# C(item_nbr)[4]                    3.8744      0.808      4.796      0.000       2.291       5.458
# C(item_nbr)[5]                   24.2185      0.808     29.977      0.000      22.635      25.802
# C(item_nbr)[6]                    4.8612      0.808      6.017      0.000       3.278       6.445
# C(item_nbr)[7]                    3.8834      0.808      4.807      0.000       2.300       5.467
# C(item_nbr)[8]                    4.5955      0.808      5.688      0.000       3.012       6.179
# C(item_nbr)[9]                   25.9001      0.808     32.058      0.000      24.317      27.484
# C(item_nbr)[10]                   3.8839      0.808      4.807      0.000       2.300       5.467
# C(item_nbr)[11]                   3.8818      0.808      4.805      0.000       2.298       5.465
# C(item_nbr)[12]                   3.8790      0.808      4.801      0.000       2.296       5.463
# C(item_nbr)[13]                   3.8806      0.808      4.803      0.000       2.297       5.464
# C(item_nbr)[14]                   3.8730      0.808      4.794      0.000       2.290       5.456
# C(item_nbr)[15]                   3.9943      0.808      4.944      0.000       2.411       5.578
# C(item_nbr)[16]                   9.3173      0.808     11.533      0.000       7.734      10.901
# C(item_nbr)[17]                   3.8835      0.808      4.807      0.000       2.300       5.467
# C(item_nbr)[18]                   3.8789      0.808      4.801      0.000       2.295       5.462
# C(item_nbr)[19]                   3.8790      0.808      4.801      0.000       2.296       5.462
# C(item_nbr)[20]                   3.8868      0.808      4.811      0.000       2.303       5.470
# C(item_nbr)[21]                   3.9069      0.808      4.836      0.000       2.323       5.490
# C(item_nbr)[22]                   3.8699      0.808      4.790      0.000       2.286       5.453
# C(item_nbr)[23]                   4.6927      0.808      5.808      0.000       3.109       6.276
# C(item_nbr)[24]                   3.9242      0.808      4.857      0.000       2.341       5.508
# C(item_nbr)[25]                   7.4298      0.808      9.196      0.000       5.846       9.013
# C(item_nbr)[26]                   3.9485      0.808      4.887      0.000       2.365       5.532
# C(item_nbr)[27]                   4.1322      0.808      5.115      0.000       2.549       5.716
# C(item_nbr)[28]                   3.9837      0.808      4.931      0.000       2.400       5.567
# C(item_nbr)[29]                   3.8860      0.808      4.810      0.000       2.303       5.469
# C(item_nbr)[30]                   3.8903      0.808      4.815      0.000       2.307       5.474
# C(item_nbr)[31]                   3.8802      0.808      4.803      0.000       2.297       5.464
# C(item_nbr)[32]                   3.8793      0.808      4.802      0.000       2.296       5.463
# C(item_nbr)[33]                   3.8743      0.808      4.795      0.000       2.291       5.458
# C(item_nbr)[34]                   3.8687      0.808      4.789      0.000       2.285       5.452
# C(item_nbr)[35]                   3.8850      0.808      4.809      0.000       2.302       5.468
# C(item_nbr)[36]                   5.8820      0.808      7.281      0.000       4.299       7.465
# C(item_nbr)[37]                   6.8746      0.808      8.509      0.000       5.291       8.458
# C(item_nbr)[38]                   3.9114      0.808      4.841      0.000       2.328       5.495
# C(item_nbr)[39]                   3.8759      0.808      4.798      0.000       2.292       5.459
# C(item_nbr)[40]                   3.8721      0.808      4.793      0.000       2.289       5.456
# C(item_nbr)[41]                   4.9808      0.808      6.165      0.000       3.397       6.564
# C(item_nbr)[42]                   3.9682      0.808      4.912      0.000       2.385       5.552
# C(item_nbr)[43]                   4.9852      0.808      6.171      0.000       3.402       6.569
# C(item_nbr)[44]                  17.7409      0.808     21.959      0.000      16.157      19.324
# C(item_nbr)[45]                  28.0274      0.808     34.691      0.000      26.444      29.611
# C(item_nbr)[90]                   3.8921      0.808      4.818      0.000       2.309       5.476
# C(item_nbr)[91]                   3.8805      0.808      4.803      0.000       2.297       5.464
# C(item_nbr)[92]                   3.8834      0.808      4.807      0.000       2.300       5.467
# C(item_nbr)[93]                   4.5370      0.808      5.616      0.000       2.953       6.120
# C(item_nbr)[94]                   3.8847      0.808      4.808      0.000       2.301       5.468
# C(item_nbr)[95]                   4.2649      0.808      5.279      0.000       2.681       5.848
# C(item_nbr)[96]                   3.8773      0.808      4.799      0.000       2.294       5.461
# C(item_nbr)[97]                   3.9104      0.808      4.840      0.000       2.327       5.494
# C(item_nbr)[98]                   3.8968      0.808      4.823      0.000       2.313       5.480
# C(item_nbr)[99]                   3.8779      0.808      4.800      0.000       2.294       5.461
# C(item_nbr)[100]                  3.8793      0.808      4.802      0.000       2.296       5.463
# C(item_nbr)[101]                  3.8769      0.808      4.799      0.000       2.293       5.460
# C(item_nbr)[102]                  3.8668      0.808      4.786      0.000       2.283       5.450
# C(item_nbr)[103]                  3.8718      0.808      4.792      0.000       2.288       5.455
# C(item_nbr)[104]                  3.8818      0.808      4.805      0.000       2.298       5.465
# C(item_nbr)[105]                  3.8814      0.808      4.804      0.000       2.298       5.465
# C(item_nbr)[106]                  3.8694      0.808      4.789      0.000       2.286       5.453
# C(item_nbr)[107]                  3.8789      0.808      4.801      0.000       2.295       5.462
# C(item_nbr)[108]                  3.9152      0.808      4.846      0.000       2.332       5.499
# C(item_nbr)[109]                  3.9672      0.808      4.910      0.000       2.384       5.551
# C(item_nbr)[110]                  3.8997      0.808      4.827      0.000       2.316       5.483
# C(item_nbr)[111]                  3.8721      0.808      4.793      0.000       2.289       5.456
# C(codesum_YN)[T.1]               -0.0369      0.010     -3.664      0.000      -0.057      -0.017
# C(is_holiday)[T.holiday_work]    -0.2576      0.027     -9.393      0.000      -0.311      -0.204
# C(is_holiday)[T.workday]         -0.2869      0.009    -30.441      0.000      -0.305      -0.268
# tmax                              0.0004      0.006      0.066      0.947      -0.011       0.012
# tmin                             -0.0040      0.006     -0.687      0.492      -0.015       0.007
# tavg                              0.0230      0.012      1.970      0.049       0.000       0.046
# depart                           -0.0002      0.001     -0.218      0.827      -0.002       0.002
# dewpoint                          0.0133      0.001     10.141      0.000       0.011       0.016
# wetbulb                          -0.0328      0.003    -11.792      0.000      -0.038      -0.027
# heat                              0.0100      0.002      5.598      0.000       0.007       0.014
# cool                              0.0010      0.002      0.586      0.558      -0.002       0.004
# sunrise                          -0.0007      0.000     -4.857      0.000      -0.001      -0.000
# sunset                            0.0006      0.000      5.940      0.000       0.000       0.001
# snowfall                         -0.0610      0.016     -3.771      0.000      -0.093      -0.029
# preciptotal                       0.0115      0.016      0.712      0.477      -0.020       0.043
# stnpressure                      -0.0524      0.003    -17.013      0.000      -0.058      -0.046
# sealevel                         -0.0961      0.027     -3.537      0.000      -0.149      -0.043
# resultspeed                      -0.0032      0.003     -1.269      0.204      -0.008       0.002
# resultdir                        -0.0026      0.000     -5.715      0.000      -0.004      -0.002
# avgspeed                          0.0282      0.003     10.123      0.000       0.023       0.034
# ===============================================================================
# Omnibus:                 16571370.255   Durbin-Watson:                    2.088
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   226194001411094.719
# Skew:                          71.601   Prob(JB):                          0.00
# Kurtosis:                   34290.374   Cond. No.                      2.30e+06
# ===============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.3e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
