# %%
from ml_config import *

# %%
sales = pd.read_csv('../data/train.csv', parse_dates=['date'])
keys = pd.read_csv('../data/key.csv')
weather = pd.read_csv('../data/weather.csv',parse_dates=['date'])
df_1 = pd.merge(weather,keys)
df_1 = pd.merge(df_1, sales)

dates = df_1['date'].dt
df_1['year'] = dates.year
df_1['month'] = dates.month
df_1['day'] = dates.day

# %%
store_7 = df_1[(df_1['year']==2013) & (df_1['store_nbr']==7)]

# %%
store
# Out:
#         station_nbr       date tmax tmin tavg depart dewpoint wetbulb heat  \
# 685758            6 2013-01-01   55   40   48     -1       43      45   17
# 685759            6 2013-01-01   55   40   48     -1       43      45   17
# 685760            6 2013-01-01   55   40   48     -1       43      45   17
# 685761            6 2013-01-01   55   40   48     -1       43      45   17
# 685762            6 2013-01-01   55   40   48     -1       43      45   17
#
#        cool ... sealevel resultspeed resultdir avgspeed store_nbr item_nbr  \
# 685758    0 ...    30.15        12.8        01     12.5         7        1
# 685759    0 ...    30.15        12.8        01     12.5         7        2
# 685760    0 ...    30.15        12.8        01     12.5         7        3
# 685761    0 ...    30.15        12.8        01     12.5         7        4
# 685762    0 ...    30.15        12.8        01     12.5         7        5
#
#        units  year month day
# 685758     0  2013     1   1
# 685759     0  2013     1   1
# 685760     0  2013     1   1
# 685761     0  2013     1   1
# 685762    52  2013     1   1
#
# [5 rows x 26 columns]
