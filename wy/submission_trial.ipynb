# %% [markdown]
# 자소서 써야 하는데 ... 한번 ols 복습 겸해서 제출해봤습니다

# %%
from set_math import *

# %% [markdown]
# # load and merge data

# %%
train = pd.read_csv("../data/basic/train.csv")
key = pd.read_csv("../data/basic/key.csv")
weather1 = pd.read_csv("../data/weather_v8_refer_prev_data.csv", index_col = 0)

# %%
df = pd.merge(train, key)

# %%
df1 = pd.merge(df, weather1)
print(df1.shape)
print(df1.columns)
df1.head()
# Out:
# (4523139, 25)
# Index(['date', 'store_nbr', 'item_nbr', 'units', 'station_nbr', 'tmax', 'tmin',
#        'tavg', 'depart', 'dewpoint', 'wetbulb', 'heat', 'cool', 'sunrise',
#        'sunset', 'codesum', 'codsum_YN', 'snowfall', 'preciptotal',
#        'stnpressure', 'sealevel', 'resultspeed', 'resultdir', 'avgspeed',
#        'month'],
#       dtype='object')
#          date  store_nbr  item_nbr  units  station_nbr  tmax  tmin  tavg  \
# 0  2012-01-01          1         1      0            1  52.0  31.0  42.0
# 1  2012-01-01          1         2      0            1  52.0  31.0  42.0
# 2  2012-01-01          1         3      0            1  52.0  31.0  42.0
# 3  2012-01-01          1         4      0            1  52.0  31.0  42.0
# 4  2012-01-01          1         5      0            1  52.0  31.0  42.0
#
#    depart  dewpoint  ...       codesum  codsum_YN  snowfall  preciptotal  \
# 0     0.0      36.0  ...    RA FZFG BR   abnormal      0.05         0.05
# 1     0.0      36.0  ...    RA FZFG BR   abnormal      0.05         0.05
# 2     0.0      36.0  ...    RA FZFG BR   abnormal      0.05         0.05
# 3     0.0      36.0  ...    RA FZFG BR   abnormal      0.05         0.05
# 4     0.0      36.0  ...    RA FZFG BR   abnormal      0.05         0.05
#
#    stnpressure sealevel resultspeed  resultdir  avgspeed  month
# 0        29.78    29.92         3.6       20.0       4.6    1.0
# 1        29.78    29.92         3.6       20.0       4.6    1.0
# 2        29.78    29.92         3.6       20.0       4.6    1.0
# 3        29.78    29.92         3.6       20.0       4.6    1.0
# 4        29.78    29.92         3.6       20.0       4.6    1.0
#
# [5 rows x 25 columns]

# %% [markdown]
# # ols

# %%
features = ['date', 'store_nbr', 'item_nbr', 'units', 'station_nbr', 'tmax', 'tmin',
       'tavg', 'depart', 'dewpoint', 'wetbulb', 'heat', 'cool', 'sunrise',
       'sunset', 'codesum', 'codsum_YN', 'snowfall', 'preciptotal',
       'stnpressure', 'sealevel', 'resultspeed', 'resultdir', 'avgspeed',
       'month']
features = " ".join(features)
features = features.replace(" ", " + ")
features
# Out:
# 'date + store_nbr + item_nbr + units + station_nbr + tmax + tmin + tavg + depart + dewpoint + wetbulb + heat + cool + sunrise + sunset + codesum + codsum_YN + snowfall + preciptotal + stnpressure + sealevel + resultspeed + resultdir + avgspeed + month'

# %%
model_1 = sm.OLS.from_formula("units ~ tavg + dewpoint + wetbulb + heat + sunrise + sunset + snowfall + stnpressure + sealevel + resultdir + avgspeed", data=df1)
result_1 = model_1.fit()
print(result_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  units   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     152.2
# Date:                Fri, 09 Mar 2018   Prob (F-statistic):               0.00
# Time:                        22:23:51   Log-Likelihood:            -1.6818e+07
# No. Observations:             4523139   AIC:                         3.364e+07
# Df Residuals:                 4523127   BIC:                         3.364e+07
# Df Model:                          11
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       5.0771      0.854      5.945      0.000       3.403       6.751
# tavg            0.0194      0.002     10.729      0.000       0.016       0.023
# dewpoint        0.0097      0.002      5.661      0.000       0.006       0.013
# wetbulb        -0.0292      0.004     -8.021      0.000      -0.036      -0.022
# heat            0.0095      0.001      9.207      0.000       0.007       0.012
# sunrise        -0.0007   9.92e-05     -6.594      0.000      -0.001      -0.000
# sunset          0.0004   6.55e-05      5.652      0.000       0.000       0.000
# snowfall       -0.0665      0.017     -3.993      0.000      -0.099      -0.034
# stnpressure    -0.0518      0.003    -16.119      0.000      -0.058      -0.045
# sealevel       -0.1050      0.029     -3.612      0.000      -0.162      -0.048
# resultdir      -0.0022      0.001     -4.341      0.000      -0.003      -0.001
# avgspeed        0.0236      0.001     17.943      0.000       0.021       0.026
# ===============================================================================
# Omnibus:                 15277122.788   Durbin-Watson:                    2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   114390206074266.484
# Skew:                          59.641   Prob(JB):                          0.00
# Kurtosis:                   24639.272   Cond. No.                      3.41e+05
# ===============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # `Rsquared, Cond. No. , Durbin-Watson`

# %% [markdown]
# # test file preprocessing

# %%
test = pd.read_csv('../data/basic/test.csv')
print(test.shape)
test.head()
# Out:
# (526917, 3)
#          date  store_nbr  item_nbr
# 0  2013-04-01          2         1
# 1  2013-04-01          2         2
# 2  2013-04-01          2         3
# 3  2013-04-01          2         4
# 4  2013-04-01          2         5

# %%
test = pd.merge(test, key)

# %%
weather_basic = pd.read_csv('../data/basic/weather.csv')

# %%
test = pd.merge(test, weather_basic)

# %%
test = pd.DataFrame(test, columns=['date', 'tmax', 'tmin', 'tavg',
       'depart', 'dewpoint', 'wetbulb', 'heat', 'cool', 'sunrise', 'sunset',
       'codesum', 'snowfall', 'preciptotal', 'stnpressure', 'sealevel',
       'resultspeed', 'resultdir', 'avgspeed', 'station_nbr', 'store_nbr', 'item_nbr'])

# %%
test.head()
# Out:
#          date tmax tmin tavg depart dewpoint wetbulb heat cool sunrise  \
# 0  2013-04-01   71   42   57      1       41      48    8    0    0617
# 1  2013-04-01   71   42   57      1       41      48    8    0    0617
# 2  2013-04-01   71   42   57      1       41      48    8    0    0617
# 3  2013-04-01   71   42   57      1       41      48    8    0    0617
# 4  2013-04-01   71   42   57      1       41      48    8    0    0617
#
#      ...    snowfall preciptotal stnpressure sealevel resultspeed resultdir  \
# 0    ...         0.0           T       28.68    30.05         9.3        04
# 1    ...         0.0           T       28.68    30.05         9.3        04
# 2    ...         0.0           T       28.68    30.05         9.3        04
# 3    ...         0.0           T       28.68    30.05         9.3        04
# 4    ...         0.0           T       28.68    30.05         9.3        04
#
#   avgspeed station_nbr store_nbr  item_nbr
# 0     11.0          14         2         1
# 1     11.0          14         2         2
# 2     11.0          14         2         3
# 3     11.0          14         2         4
# 4     11.0          14         2         5
#
# [5 rows x 22 columns]

# %%
for i in test.columns:
    test[i] = test[i].replace('-', np.nan)
    test[i] = test[i].replace(' ', np.nan)
    test[i] = test[i].replace('M', np.nan)
    test[i] = test[i].replace('T', np.nan)
    test[i] = test[i].replace('  T', np.nan)

# %%
for col in test[['tmax', 'tmin', 'tavg', 'depart', 'dewpoint', 'wetbulb', 'heat',
       'cool', 'sunrise', 'sunset', 'snowfall', 'preciptotal',
       'stnpressure', 'sealevel', 'resultspeed', 'resultdir', 'avgspeed',
       'station_nbr', 'store_nbr', 'item_nbr']]:
    test[col] = test[col].astype(np.float64)

# %%
test_sample = test.drop(columns=['date', 'codesum'])

# %% [markdown]
# # Predict
#
# codesum 컬럼에서 에러가 떴습니다.. 이 부분은 따로 제출을 위한 encoding이 필요해보입니다. 여기서는 그냥 뺐습니다.

# %%
test_result = result_1.predict(test_sample)

# %%
test_result.describe()
# Out:
# count    213120.000000
# mean          1.049434
# std           0.148640
# min           0.247689
# 25%           0.947123
# 50%           1.043345
# 75%           1.147938
# max           1.520444
# dtype: float64

# %% [markdown]
# # preprocess for submission

# %%
result = pd.concat([test, test_result], axis=1)

# %%
result['units'] = result[0]

# %%
result.describe()
# Out:
#                 tmax           tmin           tavg         depart  \
# count  525918.000000  525696.000000  522366.000000  225774.000000
# mean       77.493457      58.543497      68.256481      -1.188791
# std        17.479983      16.767699      16.769227       7.857008
# min         2.000000     -17.000000      -5.000000     -35.000000
# 25%        72.000000      52.000000      62.000000      -5.000000
# 50%        83.000000      64.000000      73.000000       0.000000
# 75%        89.000000      71.000000      80.000000       4.000000
# max       103.000000      83.000000      92.000000      22.000000
#
#             dewpoint        wetbulb           heat           cool  \
# count  524697.000000  518592.000000  522366.000000  522366.000000
# mean       56.966152      61.434075       5.153634       8.410115
# std        16.720143      15.085159      11.870129       7.322673
# min       -14.000000      -4.000000       0.000000       0.000000
# 25%        50.000000      56.000000       0.000000       0.000000
# 50%        63.000000      66.000000       0.000000       8.000000
# 75%        69.000000      72.000000       3.000000      15.000000
# max        76.000000      79.000000      70.000000      27.000000
#
#              sunrise         sunset      ...          stnpressure  \
# count  269286.000000  269286.000000      ...        525696.000000
# mean      572.145507    1856.550289      ...            29.220690
# std        72.658676      84.491956      ...             0.935632
# min       406.000000    1611.000000      ...            24.230000
# 25%       525.000000    1812.000000      ...            28.800000
# 50%       545.000000    1857.000000      ...            29.310000
# 75%       621.000000    1930.000000      ...            29.870000
# max       728.000000    1949.000000      ...            30.570000
#
#             sealevel    resultspeed      resultdir       avgspeed  \
# count  517371.000000  525585.000000  525585.000000  525696.000000
# mean       29.972497       6.774910      16.719747       8.364147
# std         0.161012       4.404095       9.164965       4.108073
# min        29.180000       0.000000       1.000000       0.800000
# 25%        29.870000       3.300000      10.000000       5.300000
# 50%        29.970000       5.800000      17.000000       7.600000
# 75%        30.060000       9.400000      22.000000      10.725000
# max        30.710000      22.600000      36.000000      23.000000
#
#          station_nbr      store_nbr      item_nbr              0  \
# count  526917.000000  526917.000000  526917.00000  213120.000000
# mean       11.012008      21.739204      56.00000       1.049434
# std         5.045622      13.257753      32.04167       0.148640
# min         1.000000       1.000000       1.00000       0.247689
# 25%         7.000000      10.000000      28.00000       0.947123
# 50%        12.000000      21.000000      56.00000       1.043345
# 75%        14.000000      33.000000      84.00000       1.147938
# max        20.000000      45.000000     111.00000       1.520444
#
#                units
# count  213120.000000
# mean        1.049434
# std         0.148640
# min         0.247689
# 25%         0.947123
# 50%         1.043345
# 75%         1.147938
# max         1.520444
#
# [8 rows x 22 columns]

# %%
result = pd.DataFrame(data=result, columns=['store_nbr', 'item_nbr', 'date', 'units'])

# %%
result.head()
# Out:
#    store_nbr  item_nbr        date     units
# 0        2.0       1.0  2013-04-01  1.148302
# 1        2.0       2.0  2013-04-01  1.148302
# 2        2.0       3.0  2013-04-01  1.148302
# 3        2.0       4.0  2013-04-01  1.148302
# 4        2.0       5.0  2013-04-01  1.148302

# %%
result['id'] = result['store_nbr'].astype(str)+'_'+result['item_nbr'].astype(str)+'_'+result['date'].astype(str)

# %%
result = result.replace(np.nan, 0)

# %%
result = pd.DataFrame(data=result, columns=['id','units'], index = None)

# %%
result['units'] = result['units'].apply(np.ceil)

# %%
result.head()
# Out:
#                id  units
# 0  2_1_2013-04-01    2.0
# 1  2_2_2013-04-01    2.0
# 2  2_3_2013-04-01    2.0
# 3  2_4_2013-04-01    2.0
# 4  2_5_2013-04-01    2.0

# %%
result.to_csv('submission_sample.csv', index=False)

# %% [markdown]
# #### 캐글에 제출 해보니까 0.76 나왔습니다

# %% [markdown]
# # 모두 0으로 제출하면 0.516 이 나온다고 하네요

# %% [markdown]
# (그리고 작을 수록 좋은거니까 ... 망)
