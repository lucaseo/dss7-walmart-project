# %% [markdown]
# # Merge All Datasets

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Load Data

# %% [markdown]
# ### _parse dates_
#
# - csv를 불러올 때, parse_dates을 적용하면 날짜 데이터를 파싱하고, 각 컬럼으로 분리, 할당할 수 있다.(아래 참조)
# - 날짜 데이터를 포함한 dataset (train, weather)데이터에는 모두 적용해서, groupby와 pivot에 유용하게 사용하자.

# %%
# train as "sales" data
sales = pd.read_csv('train.csv', parse_dates=['date'])
print(sales.shape)
sales.head()
# Out:
# (4617600, 4)
#         date  store_nbr  item_nbr  units
# 0 2012-01-01          1         1      0
# 1 2012-01-01          1         2      0
# 2 2012-01-01          1         3      0
# 3 2012-01-01          1         4      0
# 4 2012-01-01          1         5      0

# %%
# Keys : Key(station_nbr, store_nbr)
keys = pd.read_csv('key.csv')
print(keys.shape)
keys.head()
# Out:
# (45, 2)
#    store_nbr  station_nbr
# 0          1            1
# 1          2           14
# 2          3            7
# 3          4            9
# 4          5           12

# %%
# Weather Log
weather = pd.read_csv('weather.csv',parse_dates=['date'])
print(weather.shape)
weather.head()
# Out:
# (20517, 20)
#    station_nbr       date tmax tmin tavg depart dewpoint wetbulb heat cool  \
# 0            1 2012-01-01   52   31   42      M       36      40   23    0
# 1            2 2012-01-01   48   33   41     16       37      39   24    0
# 2            3 2012-01-01   55   34   45      9       24      36   20    0
# 3            4 2012-01-01   63   47   55      4       28      43   10    0
# 4            6 2012-01-01   63   34   49      0       31      43   16    0
#
#   sunrise sunset     codesum snowfall preciptotal stnpressure sealevel  \
# 0       -      -  RA FZFG BR        M        0.05       29.78    29.92
# 1    0716   1626          RA      0.0        0.07       28.82    29.91
# 2    0735   1720                  0.0        0.00       29.77    30.47
# 3    0728   1742                  0.0        0.00       29.79    30.48
# 4    0727   1742                  0.0        0.00       29.95    30.47
#
#   resultspeed resultdir avgspeed
# 0         3.6        20      4.6
# 1         9.1        23     11.3
# 2         9.9        31     10.0
# 3         8.0        35      8.2
# 4        14.0        36     13.8

# %%
df_1 = pd.merge(weather,keys)
print(df_1.shape)
df_1.head()
# Out:
# (46392, 21)
#    station_nbr       date tmax tmin tavg depart dewpoint wetbulb heat cool  \
# 0            1 2012-01-01   52   31   42      M       36      40   23    0
# 1            1 2012-01-02   50   31   41      M       26      35   24    0
# 2            1 2012-01-03   32   11   22      M        4      18   43    0
# 3            1 2012-01-04   28    9   19      M       -1      14   46    0
# 4            1 2012-01-05   38   25   32      M       13      25   33    0
#
#      ...    sunset     codesum snowfall preciptotal stnpressure sealevel  \
# 0    ...         -  RA FZFG BR        M        0.05       29.78    29.92
# 1    ...         -                    M        0.01       29.44    29.62
# 2    ...         -                    M        0.00       29.67    29.87
# 3    ...         -                    M        0.00       29.86    30.03
# 4    ...         -                    M        0.00       29.67    29.84
#
#   resultspeed resultdir avgspeed store_nbr
# 0         3.6        20      4.6         1
# 1         9.8        24     10.3         1
# 2        10.8        31     11.6         1
# 3         6.3        27      8.3         1
# 4         6.9        25      7.8         1
#
# [5 rows x 21 columns]

# %%
df_1 = pd.merge(df_1, sales)
print(df_1.shape)
df_1.tail()
# Out:
# (4617600, 23)
#          station_nbr       date tmax tmin tavg depart dewpoint wetbulb heat  \
# 4617595            5 2014-10-31    M    M    M      M       37       M    M
# 4617596            5 2014-10-31    M    M    M      M       37       M    M
# 4617597            5 2014-10-31    M    M    M      M       37       M    M
# 4617598            5 2014-10-31    M    M    M      M       37       M    M
# 4617599            5 2014-10-31    M    M    M      M       37       M    M
#
#         cool  ...  snowfall preciptotal stnpressure sealevel resultspeed  \
# 4617595    M  ...         M           M           M    30.01        10.8
# 4617596    M  ...         M           M           M    30.01        10.8
# 4617597    M  ...         M           M           M    30.01        10.8
# 4617598    M  ...         M           M           M    30.01        10.8
# 4617599    M  ...         M           M           M    30.01        10.8
#
#         resultdir avgspeed store_nbr item_nbr units
# 4617595        05        M        35      107     0
# 4617596        05        M        35      108     0
# 4617597        05        M        35      109     0
# 4617598        05        M        35      110     0
# 4617599        05        M        35      111     0
#
# [5 rows x 23 columns]

# %%
dates = df_1['date'].dt
df_2 = pd.DataFrame()
df_2['year'] = dates.year
df_2['month'] = dates.month
df_2['day'] = dates.day
df_2['station_nbr'] = df_1['station_nbr']
df_2['store_nbr'] = df_1['store_nbr']
df_2['units'] = df_1['units']

# %%
double_sort = df_2.groupby(by=['year','month','store_nbr','station_nbr']).agg('sum').reset_index()

# %%
final_sample = double_sort.sort_values(by=['year','month'])
final_sample = final_sample.drop(columns=['day'])

# %%
final_sample.head()
# Out:
#    year  month  store_nbr  station_nbr  units
# 0  2012      1          1            1   1350
# 1  2012      1          2           14   6676
# 2  2012      1          3            7   5329
# 3  2012      1          4            9   2845
# 4  2012      1          5           12   1705

# %% [markdown]
# ### Check `sales` &  `final_sample`
#
# final_sample의 월 별 units의 총합과 sales 데이터로 도출한 월 별 units의 총합은 일치하는 것을 확인했다.

# %%
sales_2 = pd.DataFrame()
dates = sales['date'].dt
sales_2['year'] = dates.year
sales_2['month'] = dates.month
sales_2['day'] = dates.day
sales_2['store_nbr'] = sales['store_nbr']
sales_2['units'] = sales['units']

sales_2.head()
# Out:
#    year  month  day  store_nbr  units
# 0  2012      1    1          1      0
# 1  2012      1    1          1      0
# 2  2012      1    1          1      0
# 3  2012      1    1          1      0
# 4  2012      1    1          1      0

# %%
sales_2_sort = sales_2.groupby(by=['year','month','store_nbr']).agg('sum').reset_index()
sales_2_sort = sales_2_sort.drop(columns=['day'])
sales_2_sort.head()
# Out:
#    year  month  store_nbr  units
# 0  2012      1          1   1350
# 1  2012      1          2   6676
# 2  2012      1          3   5329
# 3  2012      1          4   2845
# 4  2012      1          5   1705

# %% [markdown]
# # final_sample로 작업하면 됨

# %%
# ex) station 별로 처리하고 싶다
station = final_sample.pivot_table(index=['station_nbr','year','month'],values='units')
station.tail()
# Out:
#                          units
# station_nbr year month
# 20          2014 6      4772.0
#                  7      3724.0
#                  8      4095.0
#                  9      4569.0
#                  10     2664.0

# %%
# ex) 월별로 처리하고 싶다
month = final_sample.pivot_table(index=['year','month','station_nbr','store_nbr'],values='units')
month.tail()
# Out:
#                                   units
# year month station_nbr store_nbr
# 2014 10    17          31          1763
#                        34          1830
#            18          36          1695
#            19          30          2151
#            20          17          2664

# %% [markdown]
# ### 더 세부적인 조합을 위해 final_sample 에 day, codesum 데이터 추가 (final_sample_2)

# %%
df_2['codesum'] = df_1['codesum']
df_2.head()
# Out:
#    year  month  day  station_nbr  store_nbr  units     codesum
# 0  2012      1    1            1          1      0  RA FZFG BR
# 1  2012      1    1            1          1      0  RA FZFG BR
# 2  2012      1    1            1          1      0  RA FZFG BR
# 3  2012      1    1            1          1      0  RA FZFG BR
# 4  2012      1    1            1          1      0  RA FZFG BR

# %%
final_sample_2 = df_2.groupby(by=['year','month','day', 'store_nbr', 'station_nbr', 'codesum']).agg('sum').reset_index()
final_sample_2
# Out:
#        year  month  day  store_nbr  station_nbr         codesum  units
# 0      2012      1    1          1            1      RA FZFG BR     32
# 1      2012      1    1          2           14                    406
# 2      2012      1    1          3            7                    326
# 3      2012      1    1          4            9              UP     82
# 4      2012      1    1          5           12       FG+ FG BR     41
# 5      2012      1    1          6           14                    130
# 6      2012      1    1          7            6                    155
# 7      2012      1    1          8            4                     42
# 8      2012      1    1          9           17                    211
# 9      2012      1    1         10           12       FG+ FG BR    133
# 10     2012      1    1         11           10       FG+ FG BR    122
# 11     2012      1    1         12           11       FG+ FG BR     60
# 12     2012      1    1         13            6                    199
# 13     2012      1    1         14           16      RA MIFG BR     12
# 14     2012      1    1         15           13                    176
# 15     2012      1    1         16            2              RA    212
# 16     2012      1    1         17           20                    411
# 17     2012      1    1         18           17                     35
# 18     2012      1    1         19           15  RA FG+ FZFG BR     31
# 19     2012      1    1         20            7                    207
# 20     2012      1    1         21            3                    187
# 21     2012      1    1         22           10       FG+ FG BR     87
# 22     2012      1    1         23           17                     94
# 23     2012      1    1         24            9              UP    115
# 24     2012      1    1         25           13                    227
# 25     2012      1    1         26           17                    132
# 26     2012      1    1         27           10       FG+ FG BR     69
# 27     2012      1    1         28            7                    133
# 28     2012      1    1         29            3                    149
# 29     2012      1    1         30           19        RA SN BR    143
# ...     ...    ...  ...        ...          ...             ...    ...
# 41570  2014     10   31         16            2                    120
# 41571  2014     10   31         17           20                     49
# 41572  2014     10   31         18           17              RA     20
# 41573  2014     10   31         19           15                     16
# 41574  2014     10   31         20            7                     64
# 41575  2014     10   31         21            3                     79
# 41576  2014     10   31         22           10                     18
# 41577  2014     10   31         23           17              RA     51
# 41578  2014     10   31         24            9                     42
# 41579  2014     10   31         25           13                    135
# 41580  2014     10   31         26           17              RA     57
# 41581  2014     10   31         27           10                     12
# 41582  2014     10   31         28            7                     33
# 41583  2014     10   31         29            3                     42
# 41584  2014     10   31         30           19           RA SN     89
# 41585  2014     10   31         31           17              RA     67
# 41586  2014     10   31         32           13                     50
# 41587  2014     10   31         33            3                    337
# 41588  2014     10   31         34           17              RA     90
# 41589  2014     10   31         35            5                     28
# 41590  2014     10   31         36           18                     54
# 41591  2014     10   31         37           13                     47
# 41592  2014     10   31         38           14                    110
# 41593  2014     10   31         39            8              RA     21
# 41594  2014     10   31         40           13                     62
# 41595  2014     10   31         41           12              BR     52
# 41596  2014     10   31         42           14                     64
# 41597  2014     10   31         43           11                     48
# 41598  2014     10   31         44           12              BR     87
# 41599  2014     10   31         45           16                     11
#
# [41600 rows x 7 columns]
